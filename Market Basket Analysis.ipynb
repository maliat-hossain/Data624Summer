# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\malia\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from itertools import permutations
# Out:
# C:\Users\malia\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# C:\Users\malia\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mlxtend.preprocessing import TransactionEncoder
# Out:
# C:\Users\malia\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data = pd.read_csv('https://raw.githubusercontent.com/maliat-hossain/Data624Summer/main/GroceryDataSet.csv', header = None)
data.info()
# Out:
# C:\Users\malia\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9835 entries, 0 to 9834
# Data columns (total 32 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       9835 non-null   object
#  1   1       7676 non-null   object
#  2   2       6033 non-null   object
#  3   3       4734 non-null   object
#  4   4       3729 non-null   object
#  5   5       2874 non-null   object
#  6   6       2229 non-null   object
#  7   7       1684 non-null   object
#  8   8       1246 non-null   object
#  9   9       896 non-null    object
#  10  10      650 non-null    object
# ...

# %%
color = plt.cm.rainbow(np.linspace(0, 1, 40))
data[0].value_counts().head(40).plot.bar(color = color, figsize=(13,5))
plt.title('frequency of most popular items', fontsize = 20)
plt.xticks(rotation = 90 )
plt.grid()
plt.show()
# Out:
# C:\Users\malia\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Getting the list of transactions from the dataset
transactions = []
for i in range(0, len(data)):
    transactions.append([str(data.values[i,j]) for j in range(0, len(data.columns))])
# Out:
# C:\Users\malia\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Extract unique items.
flattened = [item for transaction in transactions for item in transaction]
items = list(set(flattened))
# Out:
# C:\Users\malia\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print('# of items:',len(items))
print(list(items))
# Out:
# # of items: 170
# ...

# %%
### Removing nan values
if 'nan' in items: items.remove('nan')
print(list(items))
# Out:
# ['whole milk', 'processed cheese', 'nuts/prunes', 'frozen fish', 'frozen potato products', 'sparkling wine', 'dish cleaner', 'cereals', 'chewing gum', 'softener', 'pet care', 'finished products', 'cocoa drinks', 'prosecco', 'turkey', 'rubbing alcohol', 'frankfurter', 'soups', 'pickled vegetables', 'soft cheese', 'UHT-milk', 'male cosmetics', 'cooking chocolate', 'margarine', 'misc. beverages', 'make up remover', 'long life bakery product', 'butter', 'detergent', 'rum', 'artif. sweetener', 'canned fish', 'waffles', 'candles', 'seasonal products', 'sauces', 'female sanitary products', 'bathroom cleaner', 'sound storage medium', 'semi-finished bread', 'mayonnaise', 'whipped/sour cream', 'organic products', 'napkins', 'specialty vegetables', 'skin care', 'white wine', 'baking powder', 'cream', 'citrus fruit', 'beverages', 'mustard', 'instant coffee', 'specialty bar', 'salad dressing', 'light bulbs', 'dessert', 'kitchen towels', 'red/blush wine', 'organic sausage', 'hair spray', 'honey', 
# ...

# %% [markdown]
# ### The next step  s to use a lambda function to split each transaction string into a list, thereby transforming the column into a list of lists. Then we will transform the transactions into a one-hot encoded DataFrame, where each column consists of TRUE and FALSE values that indicate whether an item was included in a transaction.

# %%
# Import the transaction encoder function from mlxtend
from mlxtend.preprocessing import TransactionEncoder

# Instantiate transaction encoder and identify unique items
encoder = TransactionEncoder().fit(transactions)

# One-hot encode transactions
onehot = encoder.transform(transactions)

# Convert one-hot encoded data to DataFrame
onehot = pd.DataFrame(onehot, columns = encoder.columns_).drop('nan', axis=1)

# Print the one-hot encoded transaction dataset
onehot.head()
# Out:
# C:\Users\malia\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
#
#    baby cosmetics  baby food   bags  baking powder  bathroom cleaner   beef  \
# 0           False      False  False          False             False  False
# ...

# %% [markdown]
# ### Here we are calculating the frequency of grocery items.

# %%
frequent_itemsets = apriori(onehot, min_support = 0.05, use_colnames =True)
frequent_itemsets = frequent_itemsets.sort_values(by = 'support', ascending = False)
frequent_itemsets
# Out:
# C:\Users\malia\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      support                        itemsets
# 26  0.255516                    (whole milk)
# 15  0.193493              (other vegetables)
# 19  0.183935                    (rolls/buns)
# 23  0.174377                          (soda)
# 27  0.139502                        (yogurt)
# 2   0.110524                 (bottled water)
# 20  0.108998               (root vegetables)
# 24  0.104931                (tropical fruit)
# 22  0.098526                 (shopping bags)
# 21  0.093950                       (sausage)
# 16  0.088968                        (pastry)
# 6   0.082766                  (citrus fruit)
# ...

# %% [markdown]
# ### Whole milk is our most frequent item followed by other vegetables.

# %%
pd.set_option('display.max_rows', None)

rules = association_rules(frequent_itemsets, metric = 'lift', min_threshold = 1)
rules.sort_values(by='lift', ascending = False).head(10)
# Out:
# C:\Users\malia\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           antecedents         consequents  antecedent support  \
# 5            (yogurt)        (whole milk)            0.139502
# 4        (whole milk)            (yogurt)            0.255516
# 1  (other vegetables)        (whole milk)            0.193493
# 0        (whole milk)  (other vegetables)            0.255516
# 2        (rolls/buns)        (whole milk)            0.183935
# 3        (whole milk)        (rolls/buns)            0.255516
#
#    consequent support   support  confidence      lift  leverage  conviction
# 5            0.255516  0.056024    0.401603  1.571735  0.020379    1.244132
# ...

# %% [markdown]
# References:
# https://pbpython.com/market-basket-analysis.html

# %% [markdown]
# https://pbpython.com/market-basket-analysis.html
